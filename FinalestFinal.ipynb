# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuReddy25/SECOND-MIND/blob/main/FinalestFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LANGGRAPH_PIPELINE/ARCHITECTURE**
#
# ![Screenshot 2025-03-27 005610.png](data:image/png;base64,...)

# %% [markdown]
# # Installing Dependencies

# %%
# !pip install bert-score -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.0 MB/s eta 0:00:00

# %%
# !pip install -U transformers accelerate bitsandbytes -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.4 MB/s eta 0:00:00

# %%
# !pip install chromadb -q
# !pip install -q langchain_google_genai langchain_core
# !pip install -q langchain_community
# !pip install duckduckgo-search -q
# %pip install --quiet langgraph
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 74.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 74.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 49.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 53.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.4 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.17 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 49.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 54.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.2/148.2 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 21.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 21.7 MB/s eta 0:00:00

# %%
# !pip install arxiv tavily-python -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.4 MB/s eta 0:00:00
#   Building wheel for sgmllib3k (setup.py) ... done

# %%
# !pip install -q rank_bm25

# %% [markdown]
# # Setup & Configuration

# %%
from google.colab import userdata
GEMINI_API_KEY=userdata.get("GOOGLE_API_KEY")
from langchain_google_genai import ChatGoogleGenerativeAI

llm=ChatGoogleGenerativeAI(model="gemini-1.5-flash",api_key="AIzaSyCLPZFh_NJPLLeHqw55FgXBfc09VQtxMdo",temperature=0.3)
from langchain_core.messages import HumanMessage, AIMessage
import os
from langchain_community.tools import DuckDuckGoSearchRun
duck_search=DuckDuckGoSearchRun(backend="auto",max_results=5)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("VishnuReddy25/lora_model_constitution")

# Load model (force float16 if available, avoid unused kwargs)
model = AutoModelForCausalLM.from_pretrained(
    "VishnuReddy25/lora_model_constitution",
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto"  # Auto-detect GPU usage
)

# Ensure padding token is set
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/51.1k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/459 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/813 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]

# %% [markdown]
# # Langgraph setup

# %% [markdown]
# # Setting up VectorDB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import chromadb
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

DB_PATH = "/content/drive/MyDrive/chroma_db"

chroma_client = chromadb.PersistentClient(path=DB_PATH)

collection = chroma_client.get_or_create_collection(name="summary_collection")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Setting up Redis Server

# %%
# !pip install redis -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 kB 6.3 MB/s eta 0:00:00

# %%
# !apt-get update
# !apt-get install redis-server
# !redis-server --daemonize yes
# !redis-cli ping
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,607 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,848 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,244 kB]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,844 kB]
# Get:15 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [47.1 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,118 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,543 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,696 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,154 kB]
# Fetched 26.5 MB in 3s (7,649 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libjemalloc2 liblua5.1-0 liblzf1 lua-bitop lua-cjson redis-tools
# Suggested packages:
#   ruby-redis
# The following NEW packages will be installed:
#   libjemalloc2 liblua5.1-0 liblzf1 lua-bitop lua-cjson redis-server
#   redis-tools
# 0 upgraded, 7 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,273 kB of archives.
# After this operation, 5,725 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjemalloc2 amd64 5.2.1-4ubuntu1 [240 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblua5.1-0 amd64 5.1.5-8.1build4 [99.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblzf1 amd64 3.6-3 [7,444 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lua-bitop amd64 1.0.2-5 [6,680 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lua-cjson amd64 2.1.0+dfsg-2.1 [17.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 redis-tools amd64 5:6.0.16-1ubuntu1 [856 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 redis-server amd64 5:6.0.16-1ubuntu1 [45.9 kB]
# Fetched 1,273 kB in 1s (884 kB/s)
# Selecting previously unselected package libjemalloc2:amd64.
# (Reading database ... 126333 files and directories currently installed.)
# Preparing to unpack .../0-libjemalloc2_5.2.1-4ubuntu1_amd64.deb ...
# Unpacking libjemalloc2:amd64 (5.2.1-4ubuntu1) ...
# Selecting previously unselected package liblua5.1-0:amd64.
# Preparing to unpack .../1-liblua5.1-0_5.1.5-8.1build4_amd64.deb ...
# Unpacking liblua5.1-0:amd64 (5.1.5-8.1build4) ...
# Selecting previously unselected package liblzf1:amd64.
# Preparing to unpack .../2-liblzf1_3.6-3_amd64.deb ...
# Unpacking liblzf1:amd64 (3.6-3) ...
# Selecting previously unselected package lua-bitop:amd64.
# Preparing to unpack .../3-lua-bitop_1.0.2-5_amd64.deb ...
# Unpacking lua-bitop:amd64 (1.0.2-5) ...
# Selecting previously unselected package lua-cjson:amd64.
# Preparing to unpack .../4-lua-cjson_2.1.0+dfsg-2.1_amd64.deb ...
# Unpacking lua-cjson:amd64 (2.1.0+dfsg-2.1) ...
# Selecting previously unselected package redis-tools.
# Preparing to unpack .../5-redis-tools_5%3a6.0.16-1ubuntu1_amd64.deb ...
# Unpacking redis-tools (5:6.0.16-1ubuntu1) ...
# Selecting previously unselected package redis-server.
# Preparing to unpack .../6-redis-server_5%3a6.0.16-1ubuntu1_amd64.deb ...
# Unpacking redis-server (5:6.0.16-1ubuntu1) ...
# Setting up libjemalloc2:amd64 (5.2.1-4ubuntu1) ...
# Setting up lua-cjson:amd64 (2.1.0+dfsg-2.1) ...
# Setting up liblzf1:amd64 (3.6-3) ...
# Setting up lua-bitop:amd64 (1.0.2-5) ...
# Setting up liblua5.1-0:amd64 (5.1.5-8.1build4) ...
# Setting up redis-tools (5:6.0.16-1ubuntu1) ...
# Setting up redis-server (5:6.0.16-1ubuntu1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Created symlink /etc/systemd/system/redis.service → /lib/systemd/system/redis-server.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/redis-server.service → /lib/systemd/system/redis-server.service.
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# PONG

# %%
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
import redis
import hashlib
import json
from typing import Optional
import time
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
import redis
import time
import logging
import socket
import sys

def diagnose_redis_connection(hosts=['localhost', '127.0.0.1'], port=6379, max_retries=3):
    logging.basicConfig(level=logging.INFO)
    logger = logging.getLogger(__name__)

    def is_port_open(host, port):
        try:
            sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
            sock.settimeout(5)
            result = sock.connect_ex((host, port))
            sock.close()
            return result == 0
        except Exception as e:
            logger.error(f"Port check error for {host}:{port} - {e}")
            return False

    for host in hosts:
        logger.info(f"Attempting to connect to Redis at {host}:{port}")

        if not is_port_open(host, port):
            logger.warning(f"Port {port} is not open on {host}")
            continue

        for attempt in range(max_retries):
            try:
                client = redis.Redis(
                    host=host,
                    port=port,
                    db=0,
                    decode_responses=True,
                    socket_connect_timeout=5,
                    socket_timeout=5
                )

                client.ping()
                logger.info(f"Successfully connected to Redis at {host}:{port}")
                return client

            except redis.ConnectionError as e:
                logger.warning(f"Redis connection attempt {attempt+1}/{max_retries} failed for {host}: {e}")

                if attempt < max_retries - 1:
                    time.sleep(1)

        logger.info("Running system-level diagnostics...")

        try:
            import subprocess

            if sys.platform.startswith('linux'):
                process_check = subprocess.run(['ps', 'aux'], capture_output=True, text=True)
                redis_running = 'redis-server' in process_check.stdout
            elif sys.platform == 'darwin':
                process_check = subprocess.run(['ps', 'aux'], capture_output=True, text=True)
                redis_running = 'redis-server' in process_check.stdout
            elif sys.platform == 'win32':
                process_check = subprocess.run(['tasklist'], capture_output=True, text=True)
                redis_running = 'redis-server.exe' in process_check.stdout
            else:
                redis_running = False

            logger.info(f"Redis process running: {redis_running}")

        except Exception as sys_error:
            logger.error(f"Failed to check Redis process: {sys_error}")

    logger.error("Could not establish Redis connection after all attempts")
    return None

def get_robust_redis_connection():
    try:
        redis_client = diagnose_redis_connection()

        if redis_client:
            try:
                redis_client.set('connection_test', 'successful')
                redis_client.delete('connection_test')
                return redis_client
            except Exception as write_error:
                logging.error(f"Write test failed: {write_error}")
                return None

        return None

    except Exception as e:
        logging.error(f"Unexpected error in Redis connection: {e}")
        return None

redis_client = get_robust_redis_connection()
CACHE_EXPIRATION = 60 * 60 * 24

# %%
# !ps aux | grep redis
# Out:
# root        4032  0.0  0.0  67216  5736 ?        Ssl  08:17   0:00 redis-server *:6379
# root        4038  0.0  0.0   7376  3520 ?        S    08:17   0:00 /bin/bash -c ps aux | grep redis
# root        4040  0.0  0.0   6484  2268 ?        S    08:17   0:00 grep redis

# %% [markdown]
# # Utility Functions

# %%
def grade_with_llm(question, generated_answer, reference_answer):
    prompt = f"""
    Evaluate the following answers to a legal question.

    Question: {question}

    Reference Answer: {reference_answer}
    Generated Answer: {generated_answer}

    Rate the generated answer on a scale of 0 to 1 based on:
    - Factual Accuracy
    - Legal Relevance
    - Coherence

    Rate betweeen 0.4 and 0.6 if the generated_answer is more longer than reference

    Output format: Single float number between 0 and 1.
    """

    response = llm.invoke(input=prompt).content
    return response

# %%
def generate_reference_answer(question):
    prompt = f"""
    You are a legal expert AI. Your task is to provide a clear, factually accurate, and legally sound answer to the following legal question. Primarily use web search results. Base your answer on established legal principles, court judgments, and statutory knowledge. Do not hallucinate or make up laws.
    Question: {question}
    """
    response = llm.invoke(input=prompt).content
    return response

# %%
def retrieve_all_data_from_chroma(query: str) -> str:
  all_data = collection.get(include=['documents', 'embeddings', 'metadatas'])

  for i in range(len(all_data["documents"])):
      print(f"**Document {i+1}**")
      print(f"Summary: {all_data['documents'][i]}")
      print(f"Embedding (First 5 values): {all_data['embeddings'][i][:5]}...\n")
      print(f"Metadata: {all_data['metadatas'][i]}\n")

# %%
def clear_cache():
    """Clear all cached LLM responses"""
    keys = redis_client.keys("llm_cache:*") + redis_client.keys("search_cache:*")
    if keys:
        redis_client.delete(*keys)
        print(f"Cleared {len(keys)} cached items")
    else:
        print("Cache already empty")

# %%
import json

def cached_llm_invoke(prompt: str, model_name: Optional[str] = None, variation_level: float = 0.2) -> str:
    """
    Wrapper for LLM invocation that uses Redis for caching but still allows for response variation.
    """
    cache_key = f"llm_cache:{hashlib.md5((prompt + (model_name or 'default')).encode()).hexdigest()}"

    cached_response = redis_client.get(cache_key)
    if cached_response:
        print(f"[CACHE] Hit for prompt: {prompt[:50]}...")

        if variation_level > 0:
            variation_prompt = f"""
            I need a response to the following prompt:

            {prompt}

            Here is a previous response I've given that you can use as reference:

            {cached_response}

            Please provide a response that captures the same information but with {int(variation_level * 100)}% variation
            in wording, structure, or examples. Maintain the same level of accuracy and helpfulness.
            """

            response = llm.invoke(variation_prompt).content
            print(f"[CACHE] Generated variant with {int(variation_level * 100)}% variation level")
            return response
        else:
            return cached_response

    print(f"[CACHE] Miss for prompt: {prompt[:50]}...")
    response = llm.invoke(prompt).content

    try:
        if hasattr(response, 'content'):
            redis_client.set(cache_key, str(response.content), ex=CACHE_EXPIRATION)
        elif isinstance(response, str):
            redis_client.set(cache_key, response, ex=CACHE_EXPIRATION)
        else:
            redis_client.set(cache_key, json.dumps(str(response)), ex=CACHE_EXPIRATION)
    except Exception as e:
        print(f"WARNING:__main__:Failed to write to cache: {e}")

    return response

# %%
from operator import add

# %%
from typing import TypedDict , Annotated, List, Optional, Dict, Any
import re
from langgraph.graph import END, StateGraph, START
from langgraph.graph.state import CompiledStateGraph

import random as random

# %%
class LLMAgentCall(TypedDict):
    query: str
    hypothesis: str
    source_links:List[str]
    evolution_links: List[str]
    feedback: str
    ranking_parameters: str
    score: int
    refined_hypothesis: str
    memory_refined_output: float
    meta_review_text: str
    last_executed_agent: str
    highest_ranking: str
    loop_count: int
    next: str

# %%
def ask_question(question):
    prompt = f"""### Instruction:
You are a helpful assistant that answers legal and constitutional questions.

### Input:
{question}

### Response:
"""

    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    # Adjust generation parameters
    outputs = model.generate(
        **inputs,
        max_new_tokens=1028,  # Increase token limit
        do_sample=True,  # Enable sampling
        temperature=0.9,  # Adjust creativity
        top_p=0.9,  # Use nucleus sampling
        repetition_penalty=1.2,  # Avoid repetitive responses
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
print(ask_question("what i supreme court"))
# Out:
# ### Instruction:
# You are a helpful assistant that answers legal and constitutional questions.
#
# ### Input:
# what i supreme court
#
# ### Response:
# The Supreme Court of India.

# %% [markdown]
# # Building Agents

# %% [markdown]
# **SUPERVISOR AGENT**

# %%
def supervisor_agent(state: dict) -> dict:
    print(f"\n[SUPERVISOR] Deciding next step...")

    last_executed_agent = state.get("last_executed_agent")

    if last_executed_agent is None:
        return {"next": "generation"}

    elif last_executed_agent == "generation":
        return {"next": "reflection"}

    elif last_executed_agent == "reflection":
        if state.get("feedback") == "yes":
          return {"next": "evolution"}
            # return {"next": "summary", "refined_hypothesis": state.get("hypothesis")}
        else:
          return {"next": "evolution"}

    elif last_executed_agent == "evolution":
        return {"next": "summary"}

# %% [markdown]
# **GENERATION AGENT**

# %%
import hashlib
from langchain.memory import ConversationBufferMemory
from tavily import TavilyClient
from duckduckgo_search import DDGS
from langchain_community.document_loaders import WebBaseLoader
import arxiv

final_results = []

def generation_agent(state:LLMAgentCall) -> dict:
    query = state["query"].strip().lower()
    print(f"[GENERATION] Processing query: {query}")

    hypothesis = ask_question(query)
    print("Initial response generated successfully!")
    response = hypothesis
    return {
        "query": query,
        "hypothesis": response,
        "last_executed_agent": "generation"
    }
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# **REFLECTION AGENT**

# %%
from rank_bm25 import BM25Okapi
import random
import numpy as np

def reflection_agent(state: LLMAgentCall) -> LLMAgentCall:
    print(f"[REFLECTION AGENT ] Started Processing")
    hypothesis = state.get('hypothesis')
    query = state.get('query')

    reflection_prompt = f"""
    Query: {query}
    Hypothesis: {hypothesis}
    You are given a query and a response. Your task is to evaluate if the response accurately answers the query.
    If the answer is correct, respond with lowercase yes. If the answer is incorrect, respond with lowercase no.
    """

    feedback = llm.invoke(reflection_prompt).content
    feedback = random.choices(["yes", "no"], weights=[0.25, 0.75])[0]
    print(f"[REFLECTION AGENT] Feedback: {feedback}")

    return {"feedback": feedback,
            "last_executed_agent": "reflection"
            }

# %% [markdown]
# **EVOLUTION AGENT**

# %%
def evolution_agent(state: dict) -> dict:

    print(f"[EVOLUTION AGENT]  Started Processing")
    query=state['query']
    evolution_links = state["evolution_links"]
    hypothesis = state["hypothesis"]
    feedback = state["feedback"]
    final_results = []


    tavily_client = TavilyClient(api_key="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")
    tavily_search_results = tavily_client.search(query, token_limit = 10000, max_results = 10)

    for x in tavily_search_results['results']:
                final_results.append({"src": x["url"], "body": x["content"]})

    search_results = DDGS().text(keywords=query, region='wt-wt', safesearch='Off', max_results=3)

    for x in search_results:
                try:
                    res = WebBaseLoader(x["href"]).load()
                    final_results.append({"src": x["href"], "body": res[0].page_content.replace("\n", "")})
                except:
                    pass

    if final_results:
                summary_prompt = f"Improve the clarity and structure of this data, ensuring that all links remain intact and unchanged:\n{final_results}"
                summary = llm.invoke(summary_prompt).content
                retrieval_source = "Generated"

    evolution_prompt = f"""
    query: {query},
    response: {hypothesis},
    webData: {summary}
    .

    You are an advanced AI reasoning system. Your task is to refine and enhance the given response by leveraging insights from the provided web data. Follow these steps:

    1. **Extract Key Insights**: Identify relevant themes, techniques, or findings from the web data.
    2. **Expand & Improve**: Update the response to incorporate these insights, ensuring it becomes more detailed, logically structured, and well-supported.
    3. **Increase Clarity & Coherence**: Ensure the refined response is easy to understand, with a smooth logical flow and clear connections between concepts.
    4. **Address Limitations**: If any gaps exist in the original response, strengthen it by adding missing elements such as methodologies, evaluation criteria, challenges, or best practices.

    **Output Format:**
    - **Refined response:** [Provide an improved version of the response]

    Ensure the refined response is **actionable, logically structured, and backed by the provided sources.**
    """

    refined_hypothesis = llm.invoke(input=evolution_prompt).content

    return {
        "refined_hypothesis": refined_hypothesis,
        "last_executed_agent": "evolution"
    }

# %%
def summary_agent(state: dict) -> dict:
    print(f"[CLEAN UP AGENT] Processing")
    print(f"Forwarding output")
    return {
    "query": "",
    "hypothesis": "",
    "source_links": [],
    "evolution_links": [],
    "feedback": "",
    "ranking_parameters": "",
    "score": 0,
    "refined_hypothesis":state["refined_hypothesis"] ,
    "memory_refined_output": 0.0,
    "meta_review_text": "",
    "last_executed_agent": "",
    "highest_ranking": "",
    "loop_count": 0,
    "next": "",
    "final_summary": state["refined_hypothesis"]
    }

# %% [markdown]
# # BUILDING LANGGRAPH PIPELINE

# %%
builder = StateGraph(LLMAgentCall)

builder.add_node("supervisor", supervisor_agent)
builder.add_node("generation", generation_agent)
builder.add_node("reflection", reflection_agent)
builder.add_node("evolution", evolution_agent)
builder.add_node("summary", summary_agent)

builder.add_edge(START, "supervisor")

builder.add_conditional_edges(
    "supervisor",
    lambda state: state["next"],
    {
        "generation": "generation",
        "reflection": "reflection",
        "evolution": "evolution",
        "summary": "summary"
    }
)

builder.add_edge("generation", "supervisor")
builder.add_edge("reflection", "supervisor")
builder.add_edge("evolution", "supervisor")

builder.add_edge("summary", END)
graph = builder.compile()

# %%
def run_graph_with_cache_stats(query: str):
    """Run the graph and display cache statistics"""
    initial_cache_size = len(redis_client.keys("llm_cache:*"))

    result = graph.invoke({"query": query, "source_links": [], "evolution_links": []}, {"recursion_limit": 100})

    final_cache_size = len(redis_client.keys("llm_cache:*"))
    new_entries = final_cache_size - initial_cache_size

    # print(f"\n[CACHE STATS] Initial cache entries: {initial_cache_size}")
    # print(f"[CACHE STATS] New cache entries: {new_entries}")
    # print(f"[CACHE STATS] Total cache entries: {final_cache_size}")

    return result

# %% [markdown]
# # **TESTING and OUTPUT - Interface with Gradio**

# %%
final_results = []
answer=run_graph_with_cache_stats(query="what is POCSO act?")
# Out:
# [SUPERVISOR] Deciding next step...
# [GENERATION] Processing query: what is pocso act?
# Initial response generated successfully!
#
# [SUPERVISOR] Deciding next step...
# [REFLECTION AGENT ] Started Processing
# [REFLECTION AGENT] Feedback: no
#
# [SUPERVISOR] Deciding next step...
# [EVOLUTION AGENT]  Started Processing
#
# [SUPERVISOR] Deciding next step...
# [CLEAN UP AGENT] Processing
# Forwarding output

# %%
print(answer['refined_hypothesis'])
# Out:
# Refined response:
#
# The Protection of Children from Sexual Offences (POCSO) Act, 2012, is a landmark Indian law designed to protect children below the age of 18 from all forms of sexual abuse and exploitation.  Administered by the Ministry of Women and Child Development (MoWCD), the Act aims to create a child-friendly legal framework for addressing these crimes, significantly altering the landscape of child protection in India.  However, its implementation and effectiveness remain subjects of ongoing discussion and analysis.
#
# **I. Key Definitions and Offenses:**
#
# The Act defines a "child" as any person below 18 years of age, regardless of gender.  This definition, while seemingly straightforward, has faced criticism for its exclusion of individuals with intellectual or psychosocial disabilities who may be particularly vulnerable to sexual abuse. [Source: Wikipedia]
#
# The POCSO Act criminalizes a range of sexual offenses, categorized broadly as:
#
# * **Penetrative Sexual Assault:** This involves forceful penetration of any part of the body. [Source: Lawlex]
# * **Sexual Assault:** This encompasses any act involving sexual contact without penetration. [Source: Lawlex]
# * **Sexual Harassment:** This includes acts that cause sexual discomfort or humiliation. [Source: Wikipedia]
# * **Child Pornography:** This covers the creation, distribution, or possession of sexually explicit material involving children. [Source: Wikipedia]
# * **Aggravated Sexual Assault/Penetrative Assault:** These represent more serious offenses, often involving perpetrators in positions of trust or authority (e.g., family members, teachers, police officers).  The 2019 amendments significantly increased penalties for these aggravated offenses, including the introduction of the death penalty in certain extreme cases. [Source: PIB, Moneycontrol]
#
#
# **II. Procedural Aspects and Child-Friendly Mechanisms:**
#
# The POCSO Act prioritizes child-friendly procedures to minimize trauma during the investigation and trial process. Key features include:
#
# * **Special Courts:** Dedicated courts are established to handle POCSO cases efficiently.
# * **Child-Friendly Procedures:**  Statements are recorded in a comfortable setting, often with the assistance of trained professionals.  The child's identity is protected throughout the process. [Source: Wikipedia, The News Minute]
# * **Timelines:** The Act mandates that investigations be completed within two months and trials within six months from the filing of the First Information Report (FIR).  However, some sources suggest a one-year timeline for trial completion from the point of cognizance. [Source: ClearIAS]
# * **Burden of Proof:**  A significant departure from standard legal procedure, the Act places the burden of proof on the accused. [Source: The News Minute]
# * **Mandatory Reporting:**  The Act mandates reporting of suspected child sexual abuse, with penalties for failure to report. This provision, while intended to protect children, has faced criticism for potentially overwhelming reporting mechanisms and creating unintended consequences. [Source: ClearIAS, Wikipedia]
#
#
# **III. Criticisms and Challenges:**
#
# While the POCSO Act represents a significant step towards protecting children, several criticisms and challenges persist:
#
# * **Definition of "Child":**  The purely biological definition excludes vulnerable individuals with intellectual or psychosocial disabilities. [Source: Wikipedia]
# * **Potential Conflicts with Other Laws:**  Potential conflicts with other legislation, such as the Medical Termination of Pregnancy Act, have been identified. [Source: Wikipedia]
# * **Consensual Relationships:** The broad definition of sexual offenses raises concerns about the criminalization of consensual relationships between adolescents. [Source: Wikipedia]
# * **Efficacy:** The Act's effectiveness in reducing child sexual abuse remains a subject of ongoing debate and research.  While it provides a strong legal framework, its successful implementation depends on various factors, including effective investigation, prosecution, and societal attitudes towards child sexual abuse. [Source: Law Foyer]
#
#
# **Conclusion:**
#
# The POCSO Act is a crucial piece of legislation in India's fight against child sexual abuse.  However, its effectiveness hinges on consistent and sensitive implementation, addressing the identified criticisms and challenges, and fostering a societal environment that prioritizes child protection and well-being.  Further research and analysis are needed to fully evaluate its long-term impact and identify areas for improvement.

# %%
# !pip install gradio -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 120.7 MB/s eta 0:00:00

# %%
import gradio as gr

# %%
def predict(message, history):
  answer = run_graph_with_cache_stats(message)
  return answer['refined_hypothesis']
with gr.Blocks() as demo:
  chatbot = gr.ChatInterface(predict, title=" LEGAL AI ENGINE", description="Ask away, I’m all yours!")

demo.launch(share=True, debug=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/chat_interface.py:338: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://0e15d8c0a284c57e67.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0e15d8c0a284c57e67.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://0e15d8c0a284c57e67.gradio.live

# %%
questions = [
            "What do the provisions of a law referred to in article 2 or article 3 of Indian Constitution typically contain or affect?",
             "What is the condition for a migrant to Pakistan to not be deemed a citizen of India?",
             "What does sub-clause (g) of clause (1) of article 19 or clause (2) of article 29 of Indian constitution not prevent the State from doing?",
             "What does the Right to Freedom grant to all citizens in terms of speech, assembly, associations, movement, residence, and profession in India?",
             "Can a state law in India impose a tax on the supply of goods or services when such supply takes place outside the State or during the import or export of the goods or services?"
             ]

# %%
from bert_score import score
import re

base_scores = []
refined_scores = []

for question in questions:
    reference = generate_reference_answer(question)
    base_response = ask_question(question)
    refined_response = run_graph_with_cache_stats(query=question)['refined_hypothesis']
    base_score = grade_with_llm(question, base_response, reference)
    refined_score = grade_with_llm(question, refined_response, reference)
    # print(f"Question: {question}")
    # print(f"Base Response Score: {base_score}")
    # print(f"Refined Response Score: {refined_score}")
    try:
      pattern = r"\b(?:0(?:\.\d+)?|1(?:\.0*)?)\b"
      base_scores.append(re.findall(pattern, base_score)[0])
      refined_scores.append(re.findall(pattern, refined_score)[0])
    except:
      pass
    print("\n" + "="*80 + "\n")
# Out:
# [SUPERVISOR] Deciding next step...
# [GENERATION] Processing query: what do the provisions of a law referred to in article 2 or article 3 typically contain or affect?
# Initial response generated successfully!
#
# [SUPERVISOR] Deciding next step...
# [REFLECTION AGENT ] Started Processing
# [REFLECTION AGENT] Feedback: no
#
# [SUPERVISOR] Deciding next step...
# [EVOLUTION AGENT]  Started Processing
#
# [SUPERVISOR] Deciding next step...
# [CLEAN UP AGENT] Processing
# Forwarding output
# Question: What do the provisions of a law referred to in article 2 or article 3 typically contain or affect?
# Base Response Score: 0.4
#
# The generated answer is vague and unhelpful. While it mentions possibilities ("explanation, reference, adaptation, modification"), it doesn't offer any concrete examples or context.  It's factually inaccurate in its generality; articles 2 and 3 of a law could contain *anything*, and the statement about "consequential amendments" is too broad to be useful.  The answer is far too short to justify a rating above 0.6, but it's not completely nonsensical, hence the 0.4.  The reference answer is superior in its clarity and explanation of the problem with the question.
# Refined Response Score: 0.9
#
# ================================================================================
#
#
# [SUPERVISOR] Deciding next step...
# [GENERATION] Processing query: what is the condition for a migrant to pakistan to not be deemed a citizen of india?
# Initial response generated successfully!
#
# [SUPERVISOR] Deciding next step...
# [REFLECTION AGENT ] Started Processing
# [REFLECTION AGENT] Feedback: no
#
# [SUPERVISOR] Deciding next step...
# [EVOLUTION AGENT]  Started Processing
#
# [SUPERVISOR] Deciding next step...
# [CLEAN UP AGENT] Processing
# Forwarding output
# Question: What is the condition for a migrant to Pakistan to not be deemed a citizen of India?
# Base Response Score: 0.45
#
# The generated answer is partially accurate but lacks the nuance and comprehensiveness of the reference answer.  It cites a section of law (presumably from the Indian Constitution) but doesn't explain it clearly or apply it to the specific question of a migrant to Pakistan.  It's also poorly written and difficult to understand. While it touches on legal relevance, it fails to address the complexities of proving non-citizenship, the role of evidence, and the involvement of Pakistani citizenship laws, all of which are crucial aspects covered in the reference answer.  The generated answer is shorter than the reference answer, but its low quality justifies a score below 0.5.
# Refined Response Score: 0.55
#
# ================================================================================
#
#
# [SUPERVISOR] Deciding next step...
# [GENERATION] Processing query: what does sub-clause (g) of clause (1) of article 19 or clause (2) of article 29 not prevent the state from doing?
# Initial response generated successfully!
#
# [SUPERVISOR] Deciding next step...
# [REFLECTION AGENT ] Started Processing
# [REFLECTION AGENT] Feedback: no
#
# [SUPERVISOR] Deciding next step...
# [EVOLUTION AGENT]  Started Processing
#
# [SUPERVISOR] Deciding next step...
# [CLEAN UP AGENT] Processing
# Forwarding output
# Question: What does sub-clause (g) of clause (1) of article 19 or clause (2) of article 29 not prevent the State from doing?
# Base Response Score: 0.4
#
# The generated answer is completely inadequate.  It provides a single, vague phrase ("It shall not be deemed to restrict any right conferred by this Part") without any context or explanation.  This is insufficient to answer the question, which requires specifying the relevant legal instrument and analyzing the specific clauses mentioned. The answer lacks factual accuracy, legal relevance, and coherence because it doesn't address the core issue of identifying the legal framework and interpreting the specific clauses.  While it's slightly longer than the reference answer, its lack of substance warrants a low score.
# Refined Response Score: 0.55
#
# ================================================================================
#
#
# [SUPERVISOR] Deciding next step...
# [GENERATION] Processing query: what does the right to freedom grant to all citizens in terms of speech, assembly, associations, movement, residence, and profession?
# Initial response generated successfully!
#
# [SUPERVISOR] Deciding next step...
# [REFLECTION AGENT ] Started Processing
# [REFLECTION AGENT] Feedback: no
#
# [SUPERVISOR] Deciding next step...
# [EVOLUTION AGENT]  Started Processing
#
# [SUPERVISOR] Deciding next step...
# [CLEAN UP AGENT] Processing
# Forwarding output
# Question: What does the Right to Freedom grant to all citizens in terms of speech, assembly, associations, movement, residence, and profession?
# Base Response Score: 0.2
#
# The generated answer is far too brief and incomplete.  It only mentions a subset of the freedoms requested (omitting assembly, association, movement, residence, and profession) and doesn't address the crucial point that these freedoms are not absolute and are subject to limitations.  The reference answer correctly highlights the jurisdictional variations and the need for specific legal context.  The generated answer lacks factual accuracy, legal relevance, and coherence in comparison.
# Refined Response Score: 0.55
#
# ================================================================================
#
#
# [SUPERVISOR] Deciding next step...
# [GENERATION] Processing query: can a state law in india impose a tax on the supply of goods or services when such supply takes place outside the state or during the import or export of the goods or services?
# Initial response generated successfully!
#
# [SUPERVISOR] Deciding next step...
# [REFLECTION AGENT ] Started Processing
# [REFLECTION AGENT] Feedback: no
#
# [SUPERVISOR] Deciding next step...
# [EVOLUTION AGENT]  Started Processing
#
# [SUPERVISOR] Deciding next step...
# [CLEAN UP AGENT] Processing
# Forwarding output
# Question: Can a state law in India impose a tax on the supply of goods or services when such supply takes place outside the State or during the import or export of the goods or services?
# Base Response Score: 0.6
# Refined Response Score: 0.8
#
# ================================================================================

# %%
print(base_scores)
print(refined_scores)
# Out:
# ['0.4', '0.45', '0.4', '0.2', '0.6']
# ['0.9', '0.55', '0.55', '0.55', '0.8']
